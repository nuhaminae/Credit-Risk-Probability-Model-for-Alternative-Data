# %% [markdown]
# # **Import Modules**

# %% [markdown]
# ## *python*

# %%
# Import python modules
import os,sys

# %% [markdown]
# ## *custom*

# %%
# Import customised modules

# Define path
sys.path.append(os.path.abspath(os.path.join('..')))

##import relevant modules
try:
    from scripts._01_EDA import EDA

except ImportError:
    print('Could not import module from `scripts/`.')

# %% [markdown]
# # **Perform Explatory Data Analysis**

# %%
# Define DataFrame path
df_path = os.path.join(os.path.dirname(os.getcwd()), 'data/raw/data.csv')
plot_path = os.path.join(os.path.dirname(os.getcwd()), 'plots/eda')
df_dir = os.path.join(os.path.dirname(os.getcwd()), 'data','processed')

# %%
# Load data
df = EDA (df_path, plot_path, df_dir)
# Out:
# DataFrame loaded successfully from ..\data\raw\data.csv
#
# DataFrame head:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# ...

# %%
# Missing values
df.missing_values()
# Out:
# There are no columns with missing values

# %%
# Summary statistics
df.summary_statistics()
# Out:
# Summary statistics for numerical features (excluding 'CountryCode' and PricingStrategy):
#              Amount         Value
# count  9.566200e+04  9.566200e+04
# mean   6.717846e+03  9.900584e+03
# std    1.233068e+05  1.231221e+05
# min   -1.000000e+06  2.000000e+00
# 25%   -5.000000e+01  2.750000e+02
# 50%    1.000000e+03  1.000000e+03
# 75%    2.800000e+03  5.000000e+03
# max    9.880000e+06  9.880000e+06

# %%
# Visualise distribution
df.visualise_distribution()
# Out:
# Visualising distribution of numerical features ...
#
#
# Plot saved to ..\plots\eda\Distribution of Amount.png
# Plot saved to ..\plots\eda\Distribution of Value.png

# %%
# Visualise value counts
df.visualise_value_count()
# Out:
# Visualising value count for categorical features ...
#
#
# Plot saved to ..\plots\eda\Frequency Distribution of 'ProductCategory'.png
# Plot saved to ..\plots\eda\Frequency Distribution of 'PricingStrategy'.png
# Plot saved to ..\plots\eda\Frequency Distribution of 'ChannelId'.png
# Plot saved to ..\plots\eda\Frequency Distribution of 'ProviderId'.png
# Plot saved to ..\plots\eda\Frequency Distribution of 'FraudResult'.png
# Plot saved to ..\plots\eda\Frequency Distribution of 'ProductId'.png

# %%
# coorelation Analysis
df.correlation_analysis()
# Out:
# Visualising correlations ...
#
#
# Plot saved to ..\plots\eda\Correlation Matrix of Numerical Features.png

# %%
# Outlier detection
df.detect_outliers()
# Out:
# Visualising outliers ...
#
#
# Plot saved to ..\plots\eda\Outlier Detection for Amount.png
# Plot saved to ..\plots\eda\Outlier Detection for Value.png
# Visualising after handling outlier ...
#
# Plot saved to ..\plots\eda\Post-Outlier Distribution of Amount.png
# Plot saved to ..\plots\eda\Post-Outlier Distribution of Value.png

# %%
# Save DataFrame
df.save_df()
# Out:
# Processed DataFrame saved to: ..\data\processed\processed_data.csv
#
# DataFrame Head:
#          TransactionId        BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871  BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770  BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203  BatchId_53941  AccountId_4229   SubscriptionId_222
# 4  TransactionId_28195  BatchId_38780  AccountId_4841  SubscriptionId_3829
# 5  TransactionId_23223  BatchId_25954  AccountId_1078  SubscriptionId_4238
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
# ...
